# %%
import numpy as np
import pandas as pd
df = pd.read_csv('iris.csv')
df #df means dataframe.
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#df.head() will give me first 5 rows. 
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10) #first 10 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail(10) #last 10 rows
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.info() #info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.head(10)) #printing first 10
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df. iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df [df ["PetalLengthCm"] > 1.5] #filtering data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5      6            5.4           3.9            1.7           0.4
# 11    12            4.8           3.4            1.6           0.2
# 18    19            5.7           3.8            1.7           0.3
# 20    21            5.4           3.4            1.7           0.2
# 23    24            5.1           3.3            1.7           0.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 5       Iris-setosa
# 11      Iris-setosa
# 18      Iris-setosa
# 20      Iris-setosa
# 23      Iris-setosa
# ..              ...
# ...

# %%
df["Sepal"] = df["SepalLengthCm"] + df["SepalWidthCm"] #adding columns
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Sepal
# 0       Iris-setosa    8.6
# 1       Iris-setosa    7.9
# 2       Iris-setosa    7.9
# 3       Iris-setosa    7.7
# ...

# %%
df.drop("Sepal", axis = 1, inplace=True)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop(5, axis=0, inplace=True)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 4      5            5.0           3.6            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 4       Iris-setosa
# 6       Iris-setosa
# ..              ...
# ...

# %%
df.columns = ["Id","SepalLength","SepalWidthCm",	"PetalLengthCm",	"PetalWidthCm",	"Species"]
df #renaming column names
# Out:
#       Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 4      5          5.0           3.6            1.4           0.2
# 6      7          4.6           3.4            1.4           0.3
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            5.2           2.3
# 146  147          6.3           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 4       Iris-setosa
# 6       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
#grouping data
grouped_data = df.groupby("Species").mean()
grouped_data
# Out:
#                          Id  SepalLength  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       26.354167      5.00625      3.414583       1.458333
# Iris-versicolor   75.500000      5.93600      2.770000       4.260000
# Iris-virginica   125.500000      6.58800      2.974000       5.552000
#
#                  PetalWidthCm
# Species
# Iris-setosa          0.241667
# Iris-versicolor      1.326000
# Iris-virginica       2.026000

# %%
df["SepalLength"].mean()
# Out:
# 5.85472972972973

# %%
#sortingdata

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.sample(10) #random samples
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 110  111            6.5           3.2            5.1           2.0
# 108  109            6.7           2.5            5.8           1.8
# 18    19            5.7           3.8            1.7           0.3
# 136  137            6.3           3.4            5.6           2.4
# 133  134            6.3           2.8            5.1           1.5
# 55    56            5.7           2.8            4.5           1.3
# 142  143            5.8           2.7            5.1           1.9
# 84    85            5.4           3.0            4.5           1.5
# 9     10            4.9           3.1            1.5           0.1
# 140  141            6.7           3.1            5.6           2.4
#
#              Species
# 110   Iris-virginica
# 108   Iris-virginica
# 18       Iris-setosa
# 136   Iris-virginica
# 133   Iris-virginica
# 55   Iris-versicolor
# 142   Iris-virginica
# 84   Iris-versicolor
# 9        Iris-setosa
# ...

# %%
#counting missing values in each column
missing_values= df.isnull().sum()
missing_values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.rename(columns={"SepalLengthCm":"SepalLength"}) #renaming only one column
# Out:
#       Id  SepalLength  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          5.1           3.5            1.4           0.2
# 1      2          4.9           3.0            1.4           0.2
# 2      3          4.7           3.2            1.3           0.2
# 3      4          4.6           3.1            1.5           0.2
# 4      5          5.0           3.6            1.4           0.2
# ..   ...          ...           ...            ...           ...
# 145  146          6.7           3.0            5.2           2.3
# 146  147          6.3           2.5            5.0           1.9
# 147  148          6.5           3.0            5.2           2.0
# 148  149          6.2           3.4            5.4           2.3
# 149  150          5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...
